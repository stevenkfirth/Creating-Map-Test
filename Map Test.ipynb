# %% [markdown]
# ## Creating a data driven map using lat and lon of high consumer off-gas postcodes
#
# The CSV file has been created by merging sub-national electricity consumption data; off-gas grid postcodes; and geographical infomation data

# %%
import pandas as pd

# %%
# !pip install folium 
import folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\cvskf\anaconda3\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\cvskf\anaconda3\lib\site-packages (from folium) (3.0.3)
# Requirement already satisfied: numpy in c:\users\cvskf\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cvskf\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cvskf\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\cvskf\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cvskf\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cvskf\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1

# %%
df = pd.read_csv('GeoCdf2.csv')
df
# Out:
#       POSTCODE  Off-gas Consumption (kWh)  Year Local Authority Name  \
# 0      AL1 3AN                    74971.2  2017            St Albans
# 1      AL1 3FJ                    90400.5  2015            St Albans
# 2      AL1 3FJ                    69959.5  2016            St Albans
# 3      AL1 3FJ                    93391.3  2017            St Albans
# 4      AL1 3FJ                   119679.5  2018            St Albans
# ...        ...                        ...   ...                  ...
# 82622  W1W 7JQ                   124010.5  2020          Westminster
# 82623  WD6 5PW                    81803.7  2020            Hertsmere
# 82624  WF1 1TE                    73866.6  2020            Wakefield
# 82625  WN2 2PY                    82763.4  2020                Wigan
# 82626  WV1 3EN                    90407.0  2020        Wolverhampton
#
#        Longitude   Latitude                Location
# 0      -0.330183  51.753791  (51.753791, -0.330183)
# 1      -0.326586  51.747634  (51.747634, -0.326586)
# 2      -0.326586  51.747634  (51.747634, -0.326586)
# 3      -0.326586  51.747634  (51.747634, -0.326586)
# 4      -0.326586  51.747634  (51.747634, -0.326586)
# ...          ...        ...                     ...
# 82622  -0.142131  51.517134  (51.517134, -0.142131)
# 82623  -0.263742  51.677875  (51.677875, -0.263742)
# 82624  -1.496868  53.681270   (53.68127, -1.496868)
# 82625  -2.574759  53.541969  (53.541969, -2.574759)
# 82626  -2.127516  52.585603  (52.585603, -2.127516)
#
# [82627 rows x 7 columns]

# %%
my_map = folium.Map(location=[51.753791, -0.330183], zoom_start=6)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e0a9aabad4745b0698923e058d5c11f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e0a9aabad4745b0698923e058d5c11f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7e0a9aabad4745b0698923e058d5c11f = L.map(
#                 &quot;map_7e0a9aabad4745b0698923e058d5c11f&quot;,
#                 {
#                     center: [51.753791, -0.330183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1b60fbcebb4498a44b786e185916a95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e0a9aabad4745b0698923e058d5c11f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker( 
        location=[51.753791, -0.330183],
        popup='Local Authority Name',
        tooltip='Local Authority Name'
    ).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e0a9aabad4745b0698923e058d5c11f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e0a9aabad4745b0698923e058d5c11f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7e0a9aabad4745b0698923e058d5c11f = L.map(
#                 &quot;map_7e0a9aabad4745b0698923e058d5c11f&quot;,
#                 {
#                     center: [51.753791, -0.330183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1b60fbcebb4498a44b786e185916a95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e0a9aabad4745b0698923e058d5c11f);
#
#
#             var marker_aabbf7d6b8721a4eab6fe63b5399cdfc = L.marker(
#                 [51.753791, -0.330183],
#                 {}
#             ).addTo(map_7e0a9aabad4745b0698923e058d5c11f);
#
#
#         var popup_dc48622ddbec87d878fb670264d2f566 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fcfc78e550cec32aff79794d514776fd = $(`&lt;div id=&quot;html_fcfc78e550cec32aff79794d514776fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Local Authority Name&lt;/div&gt;`)[0];
#             popup_dc48622ddbec87d878fb670264d2f566.setContent(html_fcfc78e550cec32aff79794d514776fd);
#
#
#         marker_aabbf7d6b8721a4eab6fe63b5399cdfc.bindPopup(popup_dc48622ddbec87d878fb670264d2f566)
#         ;
#
#
#
#
#             marker_aabbf7d6b8721a4eab6fe63b5399cdfc.bindTooltip(
#                 `&lt;div&gt;
#                      Local Authority Name
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map = folium.Map(location=[51.753791, -0.330183], zoom_start=6)

for index, row in df.iterrows():
    folium.Marker( 
        location=[row['Latitude'], row['Longitude']],
        popup=row['Local Authority Name'],
        tooltip=row['Local Authority Name']
    ).add_to(my_map)
    
    if index==100: break  # this stops after the first 100 rows

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e39136083bfc3f929d240307643336ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e39136083bfc3f929d240307643336ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e39136083bfc3f929d240307643336ea = L.map(
#                 &quot;map_e39136083bfc3f929d240307643336ea&quot;,
#                 {
#                     center: [51.753791, -0.330183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51b2bc97e16d2cc5f72d6777f196953a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#             var marker_8d0c37d80c5b5c9f5eae1932b277518c = L.marker(
#                 [51.753791, -0.330183],
#                 {}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#         var popup_b886392931ee48aa56123af8e56476de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9316ca1e1d2a134048afa1fed3705f5 = $(`&lt;div id=&quot;html_c9316ca1e1d2a134048afa1fed3705f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Albans&lt;/div&gt;`)[0];
#             popup_b886392931ee48aa56123af8e56476de.setContent(html_c9316ca1e1d2a134048afa1fed3705f5);
#
#
#         marker_8d0c37d80c5b5c9f5eae1932b277518c.bindPopup(popup_b886392931ee48aa56123af8e56476de)
#         ;
#
#
#
#
#             marker_8d0c37d80c5b5c9f5eae1932b277518c.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_44f0bd23a0c25bdc6ab37279cd7ca474 = L.marker(
#                 [51.747634, -0.326586],
#                 {}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#         var popup_3373cfcd8534fb655d689bbad69bf72e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5199d3d667f906281440b38368ce76bc = $(`&lt;div id=&quot;html_5199d3d667f906281440b38368ce76bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Albans&lt;/div&gt;`)[0];
#             popup_3373cfcd8534fb655d689bbad69bf72e.setContent(html_5199d3d667f906281440b38368ce76bc);
#
#
#         marker_44f0bd23a0c25bdc6ab37279cd7ca474.bindPopup(popup_3373cfcd8534fb655d689bbad69bf72e)
#         ;
#
#
#
#
#             marker_44f0bd23a0c25bdc6ab37279cd7ca474.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_85f7b3fa2dab5ebf26364ab4e62903b1 = L.marker(
#                 [51.747634, -0.326586],
#                 {}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#         var popup_011e746c40c266998f9c7fc487e84769 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_767d472a1fb2ac6945737a4758c8e24f = $(`&lt;div id=&quot;html_767d472a1fb2ac6945737a4758c8e24f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Albans&lt;/div&gt;`)[0];
#             popup_011e746c40c266998f9c7fc487e84769.setContent(html_767d472a1fb2ac6945737a4758c8e24f);
#
#
#         marker_85f7b3fa2dab5ebf26364ab4e62903b1.bindPopup(popup_011e746c40c266998f9c7fc487e84769)
#         ;
#
#
#
#
#             marker_85f7b3fa2dab5ebf26364ab4e62903b1.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1db45dd87ab29b1e536401b8c18b10bb = L.marker(
#                 [51.747634, -0.326586],
#                 {}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#         var popup_d49e86021c00823fbc5f305bfc270b93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c83674b0be06b4146be9f47b7376a71e = $(`&lt;div id=&quot;html_c83674b0be06b4146be9f47b7376a71e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Albans&lt;/div&gt;`)[0];
#             popup_d49e86021c00823fbc5f305bfc270b93.setContent(html_c83674b0be06b4146be9f47b7376a71e);
#
#
#         marker_1db45dd87ab29b1e536401b8c18b10bb.bindPopup(popup_d49e86021c00823fbc5f305bfc270b93)
#         ;
#
#
#
#
#             marker_1db45dd87ab29b1e536401b8c18b10bb.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ac60e35710a13286aeb3e1286eae461c = L.marker(
#                 [51.747634, -0.326586],
#                 {}
#             ).addTo(map_e39136083bfc3f929d240307643336ea);
#
#
#         var popup_04f4948aa799ac076a979baf67f689c1 = L.popup({&quot;maxWidth&quot;: &quot;1

# %%
my_map = folium.Map(location=[51.753791, -0.330183], zoom_start=6)

for _, POSTCODE in df.iterrows():
    folium.Marker( 
        location=[df['Latitude'], df['Longitude']],
        popup=df['Local Authority Name'],
        tooltip=df['Local Authority Name']
    ).add_to(my_map)

my_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      59         try:
# ---> 60             float(coord)
#      61         except (TypeError, ValueError):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17412/73435311.py in <module>
#       2
#       3 for _, POSTCODE in df.iterrows():
# ----> 4     folium.Marker(
#       5         location=[df['Latitude'], df['Longitude']],
#       6         popup=df['Local Authority Name'],
#
# ~\Anaconda3\lib\site-packages\folium\map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location) if location else None
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# ~\Anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      60             float(coord)
#      61         except (TypeError, ValueError):
# ---> 62             raise ValueError('Location should consist of two numerical values, '
#      63                              'but {!r} of type {} is not convertible to float.'
#      64                              .format(coord, type(coord)))
#
# ValueError: Location should consist of two numerical values, but 0        51.753791
# 1        51.747634
# 2        51.747634
# 3        51.747634
# 4        51.747634
#            ...
# 82622    51.517134
# 82623    51.677875
# 82624    53.681270
# 82625    53.541969
# 82626    52.585603
# Name: Latitude, Length: 82627, dtype: float64 of type <class 'pandas.core.series.Series'> is not convertible to float.
